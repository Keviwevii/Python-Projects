# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  'test1.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %% [markdown]
# Here I am using pandas to open a csv file.

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# Here I am using pandas to open a json file.

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# Here I am using pandas to open a Excel file, you also have to specify which sheetname you are using with 0 being the first one.

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# Here I am using pandas to read a file with data seperated with semicolons instead of commas.

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt", sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# If you need to add headers set your header=None and try this on your DataFrame.

# %% [markdown]
# df8.columns = ['Id', 'Address'.....]

# %% [markdown]
# If you want to change your index try this.

# %% [markdown]
# df8.set_index("ID")

# %% [markdown]
# But to permanently change it you would have to do ex:

# %% [markdown]
# df9 = df8.set_index("ID")

# %%
df7 = pandas.read_json("supermarkets.json")
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=df7.set_index("Address")

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %% [markdown]
# Indexing and Slicing

# %%
df7.loc["735 Dolores St":"332 Hill St","ID":"Country" ]
# Out:
#                 ID           City             State Country
# Address
# 735 Dolores St   2  San Francisco          CA 94119     USA
# 332 Hill St      3  San Francisco  California 94114     USA

# %% [markdown]
# To index we start at our rows and decide from which range we want and we do the same with our columns.

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.iloc[1:3,0:4]
# Out:
#                 ID           City             State Country
# Address
# 735 Dolores St   2  San Francisco          CA 94119     USA
# 332 Hill St      3  San Francisco  California 94114     USA

# %% [markdown]
# Above is the same indexing but without using labels.

# %% [markdown]
# Now we see how to delete.

# %%
df7.drop("City",1)
# Out:
#                  ID             State Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %% [markdown]
# We dropped the city column, we included the 1 to specify if we wanted to delete a column or row.

# %%
df7 = df7.drop("332 Hill St",0)

# %%
df7
# Out:
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7
# Out:
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %% [markdown]
# To add a column we can pass in our data frame with our new column name

# %%
df7["Continent"] = df7.shape[0]*["North America"]

# %%
df7
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df7.shape[0]
# Out:
# 5

# %% [markdown]
# We used shape to get the number of indexes and multiplied by NA to give continent values to each ID.

# %% [markdown]
# We can update our columns to. Here we update the continent column using an existing column.

# %%
df7["Continent"] = df7["Country"] + "," + "North America"

# %%
df7
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees          Continent
# Address
# 3666 21st St             8  USA,North America
# 735 Dolores St          15  USA,North America
# 3995 23rd St            10  USA,North America
# 1056 Sanchez St         12  USA,North America
# 551 Alvarado St         20  USA,North America

# %% [markdown]
# Adding a new row

# %%
df7_t = df7.T

# %%
df7_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# ID                         1                  2                  4
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      1056 Sanchez St    551 Alvarado St
# ID                         5                  6
# City           San Francisco      San Francisco
# State             California           CA 94114
# Country                  USA                USA
# Name                 Sanchez         Richvalley
# Employees                 12                 20
# Continent  USA,North America  USA,North America

# %%
df7_t["My address"] = [7,"My City", "My State", "My Country", "My Name", 80, "USA,North America"]

# %%
df7_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# ID                         1                  2                  4
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      1056 Sanchez St    551 Alvarado St         My address
# ID                         5                  6                  7
# City           San Francisco      San Francisco            My City
# State             California           CA 94114           My State
# Country                  USA                USA         My Country
# Name                 Sanchez         Richvalley            My Name
# ...

# %%
df7_t = df7_t.T

# %%
df7_t
# Out:
#                 ID           City       State     Country         Name  \
# Address
# 3666 21st St     1  San Francisco    CA 94114         USA      Madeira
# 735 Dolores St   2  San Francisco    CA 94119         USA  Bready Shop
# 3995 23rd St     4  San Francisco    CA 94114         USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco  California         USA      Sanchez
# 551 Alvarado St  6  San Francisco    CA 94114         USA   Richvalley
# My address       7        My City    My State  My Country      My Name
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA,North America
# 735 Dolores St         15  USA,North America
# 3995 23rd St           10  USA,North America
# 1056 Sanchez St        12  USA,North America
# 551 Alvarado St        20  USA,North America
# My address             80  USA,North America

# %% [markdown]
# Now we will use geopy

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %% [markdown]
# This is how you can convert an address string to a location.

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")
n
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292200397371, -122.43169700840102, 0.0))

# %%
n.latitude
# Out:
# 37.75292200397371

# %%
n.longitude
# Out:
# -122.43169700840102

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df = pandas.read_csv("supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]= df["Address"] +", "+ df["City"]+ ", " + df['State'] + ", " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] =df["Address"].apply(nom.geocode)
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
df.Coordinates[0].latitude
# Out:
# 37.756648011392286

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
